# %% [markdown]
# <a href="https://colab.research.google.com/github/apesnajnin1/learning-Python/blob/main/Lec2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print (123)
# Out:
# 123

# %%
print ('$$$$$')
# Out:
# $$$$$

# %%
SIZE = 10
print (SIZE)
# Out:
# 10
# 20

# %%
num1 = 23
num2 = 45.6
print (num1)
print (num2)
num1 = 78
print (num1)
print (num2)
print (num1+num2)
# Out:
# 23
# 45.6
# 78
# 45.6
# 123.6
