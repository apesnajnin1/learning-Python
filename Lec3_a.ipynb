# %% [markdown]
# <a href="https://colab.research.google.com/github/apesnajnin1/learning-Python/blob/main/Lec3_a.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = 12.2454667
print (type(x))
print (type('sdfsdf'))

print (x)
print ('x: ', x)
print (f'x: {x}')
print ('x: {:.2f}'.format(x))
print ('x: %.2f' % x)
# Out:
# <class 'float'>
# <class 'str'>
# 12.2454667
# x:  12.2454667
# x: 12.2454667
# x: 12.25
# x: 12.25

# %%
x = True
print (type(x))
# Out:
# <class 'bool'>

# %%
str1 = 'Hello'
str2 = 'World!'
str3 = str1 + ' ' + str2 + '2'
print (str3)
# Out:
# Hello World!2

# %%
x = 12.5
y = '234.56'
z = x + float (y)
print (str(x))
# Out:
# 12.5

# %%
'''
Summation
sdf asdf
sdf sadf
asdf
'''

num1 = int(input ('Put a number: '))
num2 = int(input ('Put a number: '))
print (num1 + num2)
# Out:
# Put a number:  23
# Put a number:  45
# 68

# %%
Hours = float (input ("Put Hours: "))
Rate = float (input ("Rate: "))
pay = Hours * Rate
print ("Pay: ", pay)
# Out:
# Put Hours:  42
# Rate:  12.5
# Pay:  525.0

# %%
print(f'x:{x:.2f}')
# Out:
# x:12.50

# %%
x = 5%6
print(x)
# Out:
# 5

# %%
print(9/2)
# Out:
# 4.5

# %%
jj = 23
kk = jj % 5
print(kk)
# Out:
# 3

# %%
print ( 4**3)
# Out:
# 64

# %%
eee = 'h' + 'w'
eee = eee + '1'
print (type(1))
print (eee)
# Out:
# <class 'int'>
# hw1

# %%
x = 10
y = 12.5
print(type(x))
print(type(y))
# Out:
# <class 'int'>
# <class 'float'>

# %%
print(type(x), type(y), type(1))
# Out:
# <class 'int'> <class 'float'> <class 'int'>

# %%
aval = '123'
type(aval)

aval = int(aval) + 1
print(aval)

aval = float(aval)
print(aval)

aval = str(aval)
print(aval)
# Out:
# 124
# 124

# %%
NAME = input( 'Who r u?')
print( 'Welcome', name)
# Out:
# Who r u? Dr. Najnin
# Welcome  Dr. Najnin

# %%
surname = input('Who r u?')
print('Welcome', surname)
# Out:
# Who r u? Rakeen
# Welcome  Rakeen

# %%
Age = input('How old r u?')
print('Rakeens Age is:', Age)
# Out:
# How old r u? 9
# Rakeens Age is:  9

# %%
print ('A: Hello!\nHow are you?')
print('B:I am just fine!\nHow about you?')
print('A: Yes, I also am fine!')
# Out:
# A: Hello!
# How are you?
# B:I am just fine!
# How about you?
# A: Yes, I also am fine!
